# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress

#Data-Set Generated on 2020-07-20T20:51:42+01:00

# %%
df=pd.read_csv("sample_data.csv")
df.head()
# Out:
#        date   pm25   pm10   o3   no2   so2   co
# 0  1/1/2014    225    151   21    69    40   22
# 1  1/2/2014    233    216   13    70    49   28
# 2  1/3/2014    252    173   29    52    51   22
# 3  1/4/2014    268    129   28    50    45   21
# 4  1/5/2014    189    164   40    59    49   26

# %%
df.plot.line()

# %%
df.plot.area()

# %%
fig, ax = plt.subplots(figsize=(10,7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-d0bd05e20732> in <module>
# ----> 1 mumbai_df['Specie'].value_counts()
#
# NameError: name 'mumbai_df' is not defined

# %%
rome_df=df.loc[df['City']=="Rome",:]
rome_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-0bb503d10b68> in <module>
# ----> 1 rome_df=df.loc[df['City']=="Rome",:]
#       2 rome_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'

# %%
rome_df.pivot(columns="City", values="median")
rome_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b518aa3ebe62> in <module>
# ----> 1 rome_df.pivot(columns="City", values="median")
#       2 rome_df
#
# NameError: name 'rome_df' is not defined

# %%
rome_df['Specie'].value_counts()
# Out:
# pm10           202
# no2            202
# pm25           202
# o3             202
# so2            201
# co             195
# pressure       186
# humidity       186
# temperature    186
# dew            179
# wind-gust      117
# wind-speed     117
# wind speed      74
# wind gust       73
# Name: Specie, dtype: int64

# %%
bj_df=df.loc[df['City']=="Beijing",:]
bj_df.head()
# Out:
#            Date Country     City Specie  count   min    max  median  variance
# 118164   2/9/20      CN  Beijing   pm10    118  66.0  151.0    98.0   5088.80
# 118165  5/27/20      CN  Beijing   pm10    390   1.0   89.0    17.0   3358.36
# 118166  7/17/20      CN  Beijing   pm10    385   2.0   85.0    56.0    949.14
# 118167  2/23/20      CN  Beijing   pm10    412  14.0   86.0    50.0   2764.76
# 118168  3/16/20      CN  Beijing   pm10    453   1.0   91.0    57.0    781.98

# %%
bj_df['Specie'].value_counts()
# Out:
# co               205
# so2              205
# no2              205
# pm25             205
# pm10             205
# o3               205
# pressure         188
# temperature      188
# dew              188
# humidity         188
# wind-speed       117
# wind speed        76
# wind-gust         50
# aqi               36
# wind gust         30
# pol               20
# precipitation      3
# Name: Specie, dtype: int64

# %%
milan_df=df.loc[df['City']=="Milan",:]
milan_df.head()
# Out:
#            Date Country   City Specie  count  min  max  median  variance
# 692798  2/10/20      IT  Milan     co     72  0.1  0.1     0.1       0.0
# 692799  2/14/20      IT  Milan     co     72  0.1  0.1     0.1       0.0
# 692800  3/26/20      IT  Milan     co     72  0.1  0.1     0.1       0.0
# 692801   4/6/20      IT  Milan     co     72  0.1  0.1     0.1       0.0
# 692802  4/17/20      IT  Milan     co     48  0.1  0.1     0.1       0.0

# %%
milan_df['Specie'].value_counts()
# Out:
# pm10           200
# co             200
# no2            200
# pm25           200
# o3             200
# so2            200
# pressure       184
# humidity       184
# dew            184
# temperature    184
# wind-gust      117
# wind-speed     117
# wind speed      74
# wind gust       71
# Name: Specie, dtype: int64
